# %% [markdown]
# # 01 — Interactive Tradespace Exploration
#
# Populated in **Week 10**. See `project_plan.md §6`.
#
# Intended contents:
# - Load the pretrained surrogate from `pretrained/default_surrogate.pkl`.
# - Expose design-variable sliders via `ipywidgets`.
# - Live-update range / energy-margin / slope-capability / mass readouts.
# - Let the user pick a mission scenario and re-render predictions.
#
# This is the notebook a first-time user lands on — the tradespace should feel tangible within 30 seconds.
