# %% [markdown]
# # 03 — Rediscovery Test: Does the Optimizer Recover Real Rovers?
#
# Populated in **Week 12**. See `project_plan.md §6` and §7 Layer 5.
#
# This is the headline validation result for the paper.
#
# Intended contents:
# - Load Rashid, Pragyan, Yutu-2 specs from `data/published_rovers.csv`.
# - For each rover, run NSGA-II with constraints matching its mission.
# - Compute per-variable error between the optimizer's nearest design and the real rover.
# - Plot the real rovers on top of the Pareto fronts.
# - Accept: errors within ~25–30 % and real rover on or near the front.
