# %% [markdown]
# # 04 — Reproduce All Paper Figures
#
# Populated in **Week 13**. See `project_plan.md §6`.
#
# Intended contents: a single top-to-bottom run that regenerates every figure and every quantitative result cited in the paper, pulling from the packaged pretrained surrogate and the checked-in `data/` directory.
#
# Run time target: under 15 minutes on a MacBook.
