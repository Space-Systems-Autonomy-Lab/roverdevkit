# %% [markdown]
# # 02 — Pareto Fronts Across the Four Mission Scenarios
#
# Populated in **Week 11**. See `project_plan.md §6`.
#
# Intended contents:
# - Run NSGA-II for each of the four scenarios.
# - Render the 3-D Pareto fronts (range, mass, slope) with `plotly`.
# - Highlight the constraint-feasible region on each plot.
# - Compare design-variable distributions across scenarios (which parameters move?).
